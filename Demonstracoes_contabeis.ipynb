# %%
import pandas as pd
import wget
from zipfile import ZipFile

# %%
url_base = 'https://dados.cvm.gov.br/dados/CIA_ABERTA/DOC/ITR/DADOS/'

# %%
#criando um lista com o nome de todos os arquivos, neste caso cria-se uma lista vazia, e cria um loop que irá passar por um range que vai de 2011 a 2020, sendo que o anor está prensente no link da lista
arquivo_zip = []
for ano in range(2011,2021):
    arquivo_zip.append(f'itr_cia_aberta_{ano}.zip')
    
arquivo_zip
# Out:
# ['itr_cia_aberta_2011.zip',
#  'itr_cia_aberta_2012.zip',
#  'itr_cia_aberta_2013.zip',
#  'itr_cia_aberta_2014.zip',
#  'itr_cia_aberta_2015.zip',
#  'itr_cia_aberta_2016.zip',
#  'itr_cia_aberta_2017.zip',
#  'itr_cia_aberta_2018.zip',
#  'itr_cia_aberta_2019.zip',
#  'itr_cia_aberta_2020.zip']

# %%
#realizando o download dos arquivos
for arq in arquivo_zip:
    wget.download(url_base+arq)

# %%
#Extraindo o arquivo zip, o código "extractall" permite descompactar os arquivos o "()", é a pasta que será criada, no caso, criei um pasta com o nome CVM
for arq in arquivo_zip:
    ZipFile(arq, 'r').extractall('CVM')

# %%
nomes = ['BPA_con', 'BPA_ind', 'BPP_con', 'BPP_ind','DFC_MD_con', 'DFC_MD_ind', 'DFC_MI_con', 'DFC_MI_ind', 'DMPL_con', 'DMPL_ind','DRE_con','DRE_ind', 'DVA_con', 'DVA_ind']
for nome in nomes:
    arquivo = pd.DataFrame()
    for ano in range(2011,2021):
        arquivo = pd.concat([arquivo, pd.read_csv(f'CVM/itr_cia_aberta_{nome}_{ano}.csv', sep =';', decimal = ',', encoding = 'ISO-8859-1')])
    arquivo.to_csv(f'Dados/itr_cia_aberta_{nome}_2011_2020.csv', index= False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12012/2335032611.py in <module>
#       1 nomes = ['BPA_con', 'BPA_ind', 'BPP_con', 'BPP_ind','DFC_MD_con', 'DFC_MD_ind', 'DFC_MI_con', 'DFC_MI_ind', 'DMPL_con', 'DMPL_ind','DRE_con','DRE_ind', 'DVA_con', 'DVA_ind']
#       2 for nome in nomes:
# ----> 3     arquivo = pd.DataFrame()
#       4     for ano in range(2011,2021):
#       5         arquivo = pd.concat([arquivo, pd.read_csv(f'CVM/itr_cia_aberta_{nome}_{ano}.csv', sep =';', decimal = ',', encoding = 'ISO-8859-1')])
#
# NameError: name 'pd' is not defined

# %%
caminho = 'C:\\Users\\guilh\\anaconda3\\Projetos Meus\\pasta oficial\\Demonstrações\\Dados\\'

# %%
#Vendo os dados
caminho
demonstracao = pd.read_csv(caminho + 'itr_cia_aberta_DRE_con_2011_2020.csv')

# %%
demonstracao
# Out:
#                    CNPJ_CIA    DT_REFER  VERSAO  \
# 0        00.001.180/0001-26  2011-03-31       1
# 1        00.001.180/0001-26  2011-03-31       1
# 2        00.001.180/0001-26  2011-03-31       1
# 3        00.001.180/0001-26  2011-03-31       1
# 4        00.001.180/0001-26  2011-03-31       1
# ...                     ...         ...     ...
# 1191974  97.837.181/0001-47  2020-09-30       1
# 1191975  97.837.181/0001-47  2020-09-30       1
# 1191976  97.837.181/0001-47  2020-09-30       1
# 1191977  97.837.181/0001-47  2020-09-30       1
# 1191978  97.837.181/0001-47  2020-09-30       1
#
#                                     DENOM_CIA  CD_CVM  \
# 0        CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 1        CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 2        CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 3        CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# 4        CENTRAIS ELET BRAS S.A. - ELETROBRAS    2437
# ...                                       ...     ...
# 1191974                            DEXCO S.A.   21091
# 1191975                            DEXCO S.A.   21091
# 1191976                            DEXCO S.A.   21091
# 1191977                            DEXCO S.A.   21091
# 1191978                            DEXCO S.A.   21091
#
#                                           GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 0        DF Consolidado - Demonstração do Resultado  REAL          MIL
# 1        DF Consolidado - Demonstração do Resultado  REAL          MIL
# 2        DF Consolidado - Demonstração do Resultado  REAL          MIL
# 3        DF Consolidado - Demonstração do Resultado  REAL          MIL
# 4        DF Consolidado - Demonstração do Resultado  REAL          MIL
# ...                                             ...   ...          ...
# 1191974  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 1191975  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 1191976  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 1191977  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 1191978  DF Consolidado - Demonstração do Resultado  REAL          MIL
#
#         ORDEM_EXERC DT_INI_EXERC DT_FIM_EXERC    CD_CONTA  \
# 0         PENÚLTIMO   2010-01-01   2010-03-31        3.01
# 1            ÚLTIMO   2011-01-01   2011-03-31        3.01
# 2         PENÚLTIMO   2010-01-01   2010-03-31        3.02
# 3            ÚLTIMO   2011-01-01   2011-03-31        3.02
# 4         PENÚLTIMO   2010-01-01   2010-03-31     3.02.01
# ...             ...          ...          ...         ...
# 1191974      ÚLTIMO   2020-07-01   2020-09-30     3.99.02
# 1191975   PENÚLTIMO   2019-01-01   2019-09-30  3.99.02.01
# 1191976   PENÚLTIMO   2019-07-01   2019-09-30  3.99.02.01
# 1191977      ÚLTIMO   2020-01-01   2020-09-30  3.99.02.01
# 1191978      ÚLTIMO   2020-07-01   2020-09-30  3.99.02.01
#
#                                        DS_CONTA      VL_CONTA ST_CONTA_FIXA
# 0        Receita de Venda de Bens e/ou Serviços  6.159172e+06             S
# 1        Receita de Venda de Bens e/ou Serviços  8.551982e+06             S
# 2         Custo dos Bens e/ou Serviços Vendidos -9.600600e+05             S
# 3         Custo dos Bens e/ou Serviços Vendidos -1.127021e+06             S
# 4                            Encargos Setoriais -3.406600e+05             N
# ...                                         ...           ...           ...
# 1191974                  Lucro Diluído por Ação  0.000000e+00             N
# 1191975                                      ON  1.734000e-01             N
# 1191976                                      ON  3.980000e-02             N
# 1191977                                      ON  2.187000e-01             N
# 1191978                                      ON  1.780000e-01             N
#
# [1191979 rows x 15 columns]

# %%
#Filtrando por cnpj 
# Substitua '123456789' pelo CNPJ que você deseja extrair
cnpj_desejado = '97.837.181/0001-47'

# Criando um DataFrame com as informações para o CNPJ desejados
informacoes_cnpj = demonstracao[(demonstracao['CNPJ_CIA'] == cnpj_desejado)]

# %%
informacoes_cnpj.head(10)
# Out:
#                   CNPJ_CIA    DT_REFER  VERSAO     DENOM_CIA  CD_CVM  \
# 123236  97.837.181/0001-47  2011-03-31       1  DURATEX S.A.   21091
# 123237  97.837.181/0001-47  2011-03-31       1  DURATEX S.A.   21091
# 123238  97.837.181/0001-47  2011-03-31       1  DURATEX S.A.   21091
# 123239  97.837.181/0001-47  2011-03-31       1  DURATEX S.A.   21091
# 123240  97.837.181/0001-47  2011-03-31       1  DURATEX S.A.   21091
# 123241  97.837.181/0001-47  2011-03-31       1  DURATEX S.A.   21091
# 123242  97.837.181/0001-47  2011-03-31       1  DURATEX S.A.   21091
# 123243  97.837.181/0001-47  2011-03-31       1  DURATEX S.A.   21091
# 123244  97.837.181/0001-47  2011-03-31       1  DURATEX S.A.   21091
# 123245  97.837.181/0001-47  2011-03-31       1  DURATEX S.A.   21091
#
#                                          GRUPO_DFP MOEDA ESCALA_MOEDA  \
# 123236  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 123237  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 123238  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 123239  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 123240  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 123241  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 123242  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 123243  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 123244  DF Consolidado - Demonstração do Resultado  REAL          MIL
# 123245  DF Consolidado - Demonstração do Resultado  REAL          MIL
#
#        ORDEM_EXERC DT_INI_EXERC DT_FIM_EXERC CD_CONTA  \
# 123236   PENÚLTIMO   2010-01-01   2010-03-31     3.01
# 123237      ÚLTIMO   2011-01-01   2011-03-31     3.01
# 123238   PENÚLTIMO   2010-01-01   2010-03-31     3.02
# 123239      ÚLTIMO   2011-01-01   2011-03-31     3.02
# 123240   PENÚLTIMO   2010-01-01   2010-03-31  3.02.01
# 123241      ÚLTIMO   2011-01-01   2011-03-31  3.02.01
# 123242   PENÚLTIMO   2010-01-01   2010-03-31  3.02.02
# 123243      ÚLTIMO   2011-01-01   2011-03-31  3.02.02
# 123244   PENÚLTIMO   2010-01-01   2010-03-31     3.03
# 123245      ÚLTIMO   2011-01-01   2011-03-31     3.03
#
#                                              DS_CONTA  VL_CONTA ST_CONTA_FIXA
# 123236         Receita de Venda de Bens e/ou Serviços  606580.0             S
# 123237         Receita de Venda de Bens e/ou Serviços  659865.0             S
# 123238          Custo dos Bens e/ou Serviços Vendidos -384857.0             S
# 123239          Custo dos Bens e/ou Serviços Vendidos -434847.0             S
# 123240  Variação do valor justo dos ativos biológicos   30717.0             N
# 123241  Variação do valor justo dos ativos biológicos   35603.0             N
# 123242                    Custo dos produtos vendidos -415574.0             N
# 123243                    Custo dos produtos vendidos -470450.0             N
# 123244                                Resultado Bruto  221723.0             S
# 123245                                Resultado Bruto  225018.0             S
